# %%
# Problem 1 X1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/HamedTabkhi/Intro-to-ML/main/Dataset/D3.csv'

df = pd.read_csv(url)

X1 = df.values[:, 0]  # get input values from first column
y = df.values[:, 3]   # get output values from fourth column

m = len(y)  # Number of training examples
n1 = len(X1)

from IPython.display import display
display(df)

# Scatter plot
plt.scatter(X1, y, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.title('Scatter plot of training data')

# Show the plot
plt.show()

X1_0 = np.ones((m, 1))
X1_0[:5]

X1_1 = X1.reshape(m, 1)
X1_1[:10]

X1 = np.hstack((X1_0, X1_1))
X1[:5]

theta = np.zeros(2)
theta

def compute_cost(X1, y, theta):
    predictions = X1.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    return J

cost = compute_cost(X1, y, theta)


def gradient_descent(X1, y, theta, alpha, iterations):
    m = len(y)  # Number of training examples
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X1.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X1.transpose().dot(errors)
        theta -= sum_delta
        cost_history[i] = compute_cost(X1, y, theta)

    return theta, cost_history

theta = [0., 0.]
iterations = 1500
alpha = 0.1

theta, cost_history = gradient_descent(X1, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)


plt.scatter(X1[:, 1], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X1[:, 1], X1.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()


plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent X1')

# Show the plot
plt.show()
# Out:
#           X1        X2        X3         Y
# 0   0.000000  3.440000  0.440000  4.387545
# 1   0.040404  0.134949  0.888485  2.679650
# 2   0.080808  0.829899  1.336970  2.968490
# 3   0.121212  1.524848  1.785455  3.254065
# 4   0.161616  2.219798  2.233939  3.536375
# ..       ...       ...       ...       ...
# 95  3.838384  1.460202  3.046061 -4.440595
# 96  3.878788  2.155152  3.494545 -4.458663
# 97  3.919192  2.850101  3.943030 -4.479995
# 98  3.959596  3.545051  0.391515 -3.304593
# 99  4.000000  0.240000  0.840000 -5.332455
#
# [100 rows x 4 columns]
# Final value of theta = [ 5.92794892 -2.03833663]
# cost_history = [5.16999006 4.96338989 4.7855721  ... 0.98499308 0.98499308 0.98499308]

# %%
# Problem 1 X2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/HamedTabkhi/Intro-to-ML/main/Dataset/D3.csv'

df = pd.read_csv(url)

X2 = df.values[:, 1]  # get output values from second column
y = df.values[:, 3]   # get output values from fourth column

m = len(y)  # Number of training examples
n2= len(X2)

from IPython.display import display
display(df)

# Scatter plot
plt.scatter(X2, y, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.title('Scatter plot of training data')

# Show the plot
plt.show()

X2_0 = np.ones((m, 1))
X2_0[:5]

X2_1 = X2.reshape(m, 1)
X2_1[:10]

X2 = np.hstack((X2_0, X2_1))
X2[:5]

theta = np.zeros(2)
theta

def compute_cost(X2, y, theta):
    predictions = X2.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    return J

cost = compute_cost(X1, y, theta)


def gradient_descent(X2, y, theta, alpha, iterations):
    m = len(y)  # Number of training examples
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X2.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X2.transpose().dot(errors)
        theta -= sum_delta
        cost_history[i] = compute_cost(X2, y, theta)

    return theta, cost_history

theta = [0., 0.]
iterations = 1500
alpha = 0.1

theta, cost_history = gradient_descent(X2, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)


plt.scatter(X2[:, 1], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X2[:, 1], X2.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()


plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent X2')

# Show the plot
plt.show()
# Out:
#           X1        X2        X3         Y
# 0   0.000000  3.440000  0.440000  4.387545
# 1   0.040404  0.134949  0.888485  2.679650
# 2   0.080808  0.829899  1.336970  2.968490
# 3   0.121212  1.524848  1.785455  3.254065
# 4   0.161616  2.219798  2.233939  3.536375
# ..       ...       ...       ...       ...
# 95  3.838384  1.460202  3.046061 -4.440595
# 96  3.878788  2.155152  3.494545 -4.458663
# 97  3.919192  2.850101  3.943030 -4.479995
# 98  3.959596  3.545051  0.391515 -3.304593
# 99  4.000000  0.240000  0.840000 -5.332455
#
# [100 rows x 4 columns]
# Final value of theta = [0.73606043 0.55760761]
# cost_history = [3.90731819 3.66528504 3.62832072 ... 3.59936602 3.59936602 3.59936602]

# %%
# Problem 1 X3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/HamedTabkhi/Intro-to-ML/main/Dataset/D3.csv'

df = pd.read_csv(url)

X3 = df.values[:, 2]  # get output values from third column
y = df.values[:, 3]   # get output values from fourth column

m = len(y)  # Number of training examples
n3 = len(X3)

from IPython.display import display
display(df)

# Scatter plot
plt.scatter(X3, y, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.title('Scatter plot of training data')

# Show the plot
plt.show()

X3_0 = np.ones((m, 1))
X3_0[:5]

X3_1 = X3.reshape(m, 1)
X3_1[:10]

X3 = np.hstack((X3_0, X3_1))
X3[:5]

theta = np.zeros(2)
theta

def compute_cost(X3, y, theta):
    predictions = X3.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    return J

cost = compute_cost(X3, y, theta)


def gradient_descent(X3, y, theta, alpha, iterations):
    m = len(y)  # Number of training examples
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X3.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X3.transpose().dot(errors)
        theta -= sum_delta
        cost_history[i] = compute_cost(X3, y, theta)

    return theta, cost_history

theta = [0., 0.]
iterations = 1500
alpha = 0.1

theta, cost_history = gradient_descent(X3, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)


plt.scatter(X3[:, 1], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(X3[:, 1], X3.dot(theta), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.title('Linear Regression Fit')
plt.legend()

# Show the plot
plt.show()


plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent X3')

# Show the plot
plt.show()
# Out:
#           X1        X2        X3         Y
# 0   0.000000  3.440000  0.440000  4.387545
# 1   0.040404  0.134949  0.888485  2.679650
# 2   0.080808  0.829899  1.336970  2.968490
# 3   0.121212  1.524848  1.785455  3.254065
# 4   0.161616  2.219798  2.233939  3.536375
# ..       ...       ...       ...       ...
# 95  3.838384  1.460202  3.046061 -4.440595
# 96  3.878788  2.155152  3.494545 -4.458663
# 97  3.919192  2.850101  3.943030 -4.479995
# 98  3.959596  3.545051  0.391515 -3.304593
# 99  4.000000  0.240000  0.840000 -5.332455
#
# [100 rows x 4 columns]
# Final value of theta = [ 2.8714221  -0.52048288]
# cost_history = [4.66843939 4.49602325 4.43685075 ... 3.62945112 3.62945112 3.62945112]

# %%
# Problem 2 X1,X2,X3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/HamedTabkhi/Intro-to-ML/main/Dataset/D3.csv'

df = pd.read_csv(url)

print(df.head())

X = df.values[:, :3]  # get input values from first-third column
y = df.values[:, 3]   # get output values from fourth column

m = len(y)  # Number of training examples
n = len(X)

# Display first 5 records and the total number of training examples
print('X = ', X[: 5])
print('y = ', y[: 5])
print('m = ', m)
print('n = ', n)

from IPython.display import display
display(df)


X_0 = np.ones((m, 1))
X_0[:5]
# reshape matrix with correct dimensions
X_1 = X.reshape(m, 3)
X_1[:10]

X = np.hstack((X_0, X_1))
X[:5]
# theta has the three input variables and a single outpput variable
theta = np.zeros(4)
theta
print (theta)

def compute_cost(X, y, theta):
    predictions = X.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    return J

cost = compute_cost(X, y, theta)


def gradient_descent(X, y, theta, alpha, iterations):
    m = len(y)  # Number of training examples
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X.transpose().dot(errors)
        theta -= sum_delta
        cost_history[i] = compute_cost(X, y, theta)

    return theta, cost_history
# add the extra dimensions to theta
theta = [0., 0., 0., 0.]
iterations = 1500
alpha = 0.05

theta, cost_history = gradient_descent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)


plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

# Show the plot
plt.show()

def predict_y(x1, x2, x3, theta):
       return theta[0] + theta[1]*x1 + theta[2]*x2 + theta[3]*x3

# (1, 1, 1)
Y1 = predict_y(1, 1, 1, theta)
# (2, 0, 4)
Y2 = predict_y(2, 0, 4, theta)
# (3, 2, 1)
Y3 = predict_y(3, 2, 1, theta)

print(f"Predicted y for (1, 1, 1): {Y1}")
print(f"Predicted y for (2, 0, 4): {Y2}")
print(f"Predicted y for (3, 2, 1): {Y3}")
# Out:
#          X1        X2        X3         Y
# 0  0.000000  3.440000  0.440000  4.387545
# 1  0.040404  0.134949  0.888485  2.679650
# 2  0.080808  0.829899  1.336970  2.968490
# 3  0.121212  1.524848  1.785455  3.254065
# 4  0.161616  2.219798  2.233939  3.536375
# X =  [[0.         3.44       0.44      ]
#  [0.04040404 0.1349495  0.88848485]
#  [0.08080808 0.82989899 1.3369697 ]
#  [0.12121212 1.52484848 1.78545454]
#  [0.16161616 2.21979798 2.23393939]]
# y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100
# n =  100
#           X1        X2        X3         Y
# 0   0.000000  3.440000  0.440000  4.387545
# 1   0.040404  0.134949  0.888485  2.679650
# 2   0.080808  0.829899  1.336970  2.968490
# 3   0.121212  1.524848  1.785455  3.254065
# 4   0.161616  2.219798  2.233939  3.536375
# ..       ...       ...       ...       ...
# 95  3.838384  1.460202  3.046061 -4.440595
# 96  3.878788  2.155152  3.494545 -4.458663
# 97  3.919192  2.850101  3.943030 -4.479995
# 98  3.959596  3.545051  0.391515 -3.304593
# 99  4.000000  0.240000  0.840000 -5.332455
#
# [100 rows x 4 columns]
# [0. 0. 0. 0.]
# Final value of theta = [ 5.31128136 -2.0033116   0.5330402  -0.26517886]
# cost_history = [4.35632837 3.99754934 3.73994659 ... 0.73846469 0.73846469 0.73846469]
# Predicted y for (1, 1, 1): 3.575831095534636
# Predicted y for (2, 0, 4): 0.2439427039331008
# Predicted y for (3, 2, 1): 0.10224809362461551
